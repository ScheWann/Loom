# %%
import scanpy as sc
import os
import bin2cell as b2c
import celltypist
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import median_abs_deviation
from PIL import Image

# %%
file_path = "../Example_Data/skin_TXK6Z4X_D1/binned_outputs/square_008um"
source_image_path = "../Example_Data/H1-TXK6Z4X-D1_SK24-001_A1-5-004.tiff"
os.makedirs("stardist", exist_ok=True)
bdata = b2c.read_visium(file_path, source_image_path = source_image_path)
bdata.var_names_make_unique()
bdata
# Out:
# AnnData object with n_obs × n_vars = 600354 × 18085
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
bdata.raw = bdata

# %%
sc.pp.filter_genes(bdata, min_cells=3)
sc.pp.filter_cells(bdata, min_genes=100)
bdata.var["mt"] = bdata.var_names.str.startswith("MT-")
sc.pp.calculate_qc_metrics(bdata, qc_vars=["mt"], percent_top=[20], inplace=True)

# %%
p1 = sc.pl.violin(bdata, "pct_counts_mt")
p2 = sns.displot(bdata.obs["total_counts"])
p3 = sc.pl.scatter(bdata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")
# Out:
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical

# %%
def is_outlier(adata, metric: str, nmads: int):
    M = adata.obs[metric]
    outlier = (M < np.median(M) - nmads * median_abs_deviation(M)) | (
        np.median(M) + nmads * median_abs_deviation(M) < M
    )
    return outlier

# %%
bdata.obs["outlier"] = (
    is_outlier(bdata, "log1p_total_counts", 5)
    | is_outlier(bdata, "log1p_n_genes_by_counts", 5)
    | is_outlier(bdata, "pct_counts_in_top_20_genes", 5)
)
bdata.obs.outlier.value_counts()
# Out:
# outlier
# False    4103
# True       13
# Name: count, dtype: int64

# %%
bdata.obs["mt_outlier"] = is_outlier(bdata, "pct_counts_mt", 3) | (
    bdata.obs["pct_counts_mt"] > 8
)
bdata.obs.mt_outlier.value_counts()
# Out:
# mt_outlier
# False    3941
# True      175
# Name: count, dtype: int64

# %%
p1 = sc.pl.scatter(bdata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")

# %%
sc.pp.highly_variable_genes(bdata,n_top_genes=5000,flavor="seurat_v3")
sc.pp.normalize_total(bdata,target_sum=1e4)
sc.pp.log1p(bdata)
predictions_8bin = celltypist.annotate(bdata, model = 'Adult_Human_Skin.pkl')
bdata = predictions_8bin.to_adata()
bdata
# Out:
# 🔬 Input data has 4116 cells and 17897 genes
# 🔗 Matching reference genes in the model
# 🧬 2949 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# AnnData object with n_obs × n_vars = 4116 × 17897
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'outlier', 'mt_outlier', 'predicted_labels', 'conf_score'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'spatial', 'hvg', 'log1p'
#     obsm: 'spatial'

# %%
bdata = bdata[:, bdata.var["highly_variable"]].copy()
sc.pp.scale(bdata, max_value=10)
sc.pp.pca(bdata, use_highly_variable=True)
sc.pp.neighbors(bdata)
sc.tl.umap(bdata)
# Out:
# auto.py (21): IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# 2025-11-18 16:28:14.513417: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-18 16:28:14.675894: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763504894.732987   62791 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763504894.748632   62791 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763504894.885657   62791 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763504894.885683   62791 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763504894.885685   62791 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763504894.885686   62791 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-18 16:28:14.900017: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 4116 × 5000
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'outlier', 'mt_outlier', 'predicted_labels', 'conf_score'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'spatial', 'hvg', 'log1p', 'pca', 'neighbors', 'umap'
#     obsm: 'spatial', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
sc.set_figure_params(
    dpi=50,
    fontsize=10,
)
sc.pl.violin(
    bdata,
    [
        "n_genes_by_counts",
        "log1p_n_genes_by_counts",
        "total_counts",
        "log1p_total_counts",
        "pct_counts_in_top_20_genes",
    ],
    jitter=0.1,
    multi_panel=True,
)

# %%
sc.set_figure_params(dpi=100,fontsize=10,)

sc.tl.leiden(bdata,resolution=1,key_added='leiden')
sc.pl.umap(bdata,color=['leiden'],size=2,wspace=0.25,frameon=False)

# %%
b2c.scaled_he_image(bdata, mpp=0.5, save_path="stardist/he.tiff")
# Out:
# Cropped spatial coordinates key: spatial_cropped_150_buffer
# Image key: 0.5_mpp_150_buffer

# %%
bdata.var["highly_variable"]
# Out:
# NOC2L       True
# PLEKHN1     True
# ISG15       True
# RNF223      True
# TNFRSF18    True
#             ...
# CMC4        True
# BRCC3       True
# ZFY         True
# PRKY        True
# MT-ND5      True
# Name: highly_variable, Length: 5000, dtype: bool

# %%
gene = "NOC2L"

bg_img = Image.open("./stardist/he.tiff")
bg_width, bg_height = bg_img.size

coords = bdata.obsm["spatial_cropped_150_buffer"]
expr = bdata[:, gene].X.toarray().flatten()

plt.figure(figsize=(6, 6))
plt.imshow(bg_img, extent=[0, bg_width, bg_height, 0])
plt.scatter(coords[:, 0], coords[:, 1], c=expr, cmap="viridis", s=0.1, alpha=0.7)
plt.colorbar(label=f"{gene} expression")
plt.title(f"Spatial expression of {gene}")
plt.axis("equal")
plt.xlim(0, bg_width)
plt.ylim(bg_height, 0) 
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
bdata.raw.to_adata().write('skin_TXK6Z4X_D1_8um_b2c_qc.h5ad')
# Out:
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
